-- %% [markdown]
-- # Welcome to Notebook session for test
--
-- ## This is a user group meeting
--
-- ## **Notebooks**\- ALL in One books (Code+text, executable code)
--
-- ![](attachment:image.png)
--
-- Image source: [https://www.amazon.in/Golden-Class-English-Hindi-Mathematics/dp/812244976X/ref=sr\_1\_5?crid=TI8AXXP7JORL&keywords=all+in+one+book+all+subjects&qid=1642763973&s=books&sprefix=all+in+one+book+all+subjects+%2Cstripbooks%2C164&sr=1-5](https://www.amazon.in/Golden-Class-English-Hindi-Mathematics/dp/812244976X/ref=sr_1_5?crid=TI8AXXP7JORL&keywords=all+in+one+book+all+subjects&qid=1642763973&s=books&sprefix=all+in+one+book+all+subjects+%2Cstripbooks%2C164&sr=1-5)
--
-- ### We are going to learn about our first notebook in 10 minutes
--
-- ### **You** _can_ <u>edit</u> <mark>your</mark> DATA **_as per your needs_**
--
-- ### **Different Kurnels**

-- %%
Select * from sysdatabases

-- %% [markdown]
-- ### Collapse cells
--
-- ### Clear results
--
-- ### Export notebooks to sql and vice versa
--
-- # Uses of SQL Notebooks
--
-- ###
--
-- 1. Share with you friends and collegues
-- 2. Code reviews
-- 3. Saving data before modifying data
-- 4. Documentation
-- 5. Auditing made easier
-- 6. Visualization and analysis purposes
-- 7. Not only the data scientists, DBA's, developers can use it
